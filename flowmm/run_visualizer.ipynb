# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# metrics_path = "runs/trash/2024-06-19/20-37-46/null_params-rfm_cspnet-jgdq0cz6/lightning_logs/version_0/metrics.csv"
# metrics_path = "runs/trash/2024-06-20/00-36-02/null_params-rfm_cspnet-t1mia7i1/lightning_logs/version_0/metrics.csv"
metrics_path = "runs/trash/2024-06-20/01-00-06/abits_params-rfm_cspnet-oqdld5i5/lightning_logs/version_0/metrics.csv"

# %%
df = pd.read_csv(metrics_path)
df
# Out:
#       lr-AdamW    step  train/loss  train/loss_a  train/loss_f  train/loss_l
# 0     0.000300      49         NaN           NaN           NaN           NaN  \
# 1          NaN      49    0.234335      0.146555      0.058988      0.028792
# 2     0.000300      99         NaN           NaN           NaN           NaN
# 3          NaN      99    0.227640      0.155002      0.055376      0.017263
# 4     0.000300     149         NaN           NaN           NaN           NaN
# ...        ...     ...         ...           ...           ...           ...
# 8016       NaN  191399    0.060920      0.038948      0.020545      0.001427
# 8017  0.000277  191449         NaN           NaN           NaN           NaN
# 8018       NaN  191449    0.045957      0.016232      0.029201      0.000523
# 8019  0.000277  191499         NaN           NaN           NaN           NaN
# 8020       NaN  191499    0.120539      0.076014      0.035927      0.008599
#
#       train/loss_ce  train/unscaled/loss_a  train/unscaled/loss_f
# 0               NaN                    NaN                    NaN  \
# 1               0.0               1.615771               0.065034
# 2               NaN                    NaN                    NaN
# 3               0.0               1.708893               0.061052
# 4               NaN                    NaN                    NaN
# ...             ...                    ...                    ...
# 8016            0.0               0.429397               0.022651
# 8017            NaN                    NaN                    NaN
# 8018            0.0               0.178959               0.032194
# 8019            NaN                    NaN                    NaN
# 8020            0.0               0.838052               0.039609
#
#       train/unscaled/loss_l  ...  val/unscaled/loss_ce  val/best/loss
# 0                       NaN  ...                   NaN            NaN  \
# 1                 12.697315  ...                   NaN            NaN
# 2                       NaN  ...                   NaN            NaN
# 3                  7.612876  ...                   NaN            NaN
# 4                       NaN  ...                   NaN            NaN
# ...                     ...  ...                   ...            ...
# 8016               0.629369  ...                   NaN            NaN
# 8017                    NaN  ...                   NaN            NaN
# 8018               0.230806  ...                   NaN            NaN
# 8019                    NaN  ...                   NaN            NaN
# 8020               3.791950  ...                   NaN            NaN
#
#       val/best/loss_a  val/best/loss_f  val/best/loss_l  val/best/loss_ce
# 0                 NaN              NaN              NaN               NaN  \
# 1                 NaN              NaN              NaN               NaN
# 2                 NaN              NaN              NaN               NaN
# 3                 NaN              NaN              NaN               NaN
# 4                 NaN              NaN              NaN               NaN
# ...               ...              ...              ...               ...
# 8016              NaN              NaN              NaN               NaN
# 8017              NaN              NaN              NaN               NaN
# 8018              NaN              NaN              NaN               NaN
# 8019              NaN              NaN              NaN               NaN
# 8020              NaN              NaN              NaN               NaN
#
#       val/best/unscaled/loss_a  val/best/unscaled/loss_f
# 0                          NaN                       NaN  \
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 8016                       NaN                       NaN
# 8017                       NaN                       NaN
# 8018                       NaN                       NaN
# 8019                       NaN                       NaN
# 8020                       NaN                       NaN
#
#       val/best/unscaled/loss_l  val/best/unscaled/loss_ce
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 8016                       NaN                        NaN
# 8017                       NaN                        NaN
# 8018                       NaN                        NaN
# 8019                       NaN                        NaN
# 8020                       NaN                        NaN
#
# [8021 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['lr-AdamW', 'step', 'train/loss', 'train/loss_a', 'train/loss_f',
#        'train/loss_l', 'train/loss_ce', 'train/unscaled/loss_a',
#        'train/unscaled/loss_f', 'train/unscaled/loss_l',
#        'train/unscaled/loss_ce', 'epoch', 'val/loss', 'val/loss_a',
#        'val/loss_f', 'val/loss_l', 'val/loss_ce', 'val/unscaled/loss_a',
#        'val/unscaled/loss_f', 'val/unscaled/loss_l', 'val/unscaled/loss_ce',
#        'val/best/loss', 'val/best/loss_a', 'val/best/loss_f',
#        'val/best/loss_l', 'val/best/loss_ce', 'val/best/unscaled/loss_a',
#        'val/best/unscaled/loss_f', 'val/best/unscaled/loss_l',
#        'val/best/unscaled/loss_ce'],
#       dtype='object')

# %%
xy = df[['step', 'train/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='train loss')
xy = df[['step', 'val/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='val loss')
xy = df[['step', 'val/best/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='val best loss')
plt.legend()
