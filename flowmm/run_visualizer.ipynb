# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# metrics_path = "runs/trash/2024-06-19/20-07-42/null_params-rfm_cspnet-elf43kbt/lightning_logs/version_0/metrics.csv"

metrics_path = "runs/trash/2024-06-19/20-37-46/null_params-rfm_cspnet-jgdq0cz6/lightning_logs/version_0/metrics.csv"

# %%
df = pd.read_csv(metrics_path)
df
# Out:
#       lr-AdamW    step  train/loss  train/loss_a  train/loss_f  train/loss_l  \
# 0      0.00030      49         NaN           NaN           NaN           NaN
# 1          NaN      49    0.097992           0.0      0.067517      0.030475
# 2      0.00030      99         NaN           NaN           NaN           NaN
# 3          NaN      99    0.058294           0.0      0.048414      0.009880
# 4      0.00030     149         NaN           NaN           NaN           NaN
# ...        ...     ...         ...           ...           ...           ...
# 4435   0.00001  105949         NaN           NaN           NaN           NaN
# 4436       NaN  105949    0.020393           0.0      0.020170      0.000222
# 4437   0.00001  105999         NaN           NaN           NaN           NaN
# 4438       NaN  105999    0.010360           0.0      0.010204      0.000155
# 4439       NaN  105999         NaN           NaN           NaN           NaN
#
#       train/loss_ce  train/unscaled/loss_a  train/unscaled/loss_f  \
# 0               NaN                    NaN                    NaN
# 1               0.0                    0.0               0.067686
# 2               NaN                    NaN                    NaN
# 3               0.0                    0.0               0.048535
# 4               NaN                    NaN                    NaN
# ...             ...                    ...                    ...
# 4435            NaN                    NaN                    NaN
# 4436            0.0                    0.0               0.020221
# 4437            NaN                    NaN                    NaN
# 4438            0.0                    0.0               0.010230
# 4439            NaN                    NaN                    NaN
#
#       train/unscaled/loss_l  ...  val/unscaled/loss_ce  val/best/loss  \
# 0                       NaN  ...                   NaN            NaN
# 1                 12.220325  ...                   NaN            NaN
# 2                       NaN  ...                   NaN            NaN
# 3                  3.961875  ...                   NaN            NaN
# 4                       NaN  ...                   NaN            NaN
# ...                     ...  ...                   ...            ...
# 4435                    NaN  ...                   NaN            NaN
# 4436               0.089201  ...                   NaN            NaN
# 4437                    NaN  ...                   NaN            NaN
# 4438               0.062336  ...                   NaN            NaN
# 4439                    NaN  ...                   0.0       0.030463
#
#       val/best/loss_a  val/best/loss_f  val/best/loss_l  val/best/loss_ce  \
# 0                 NaN              NaN              NaN               NaN
# 1                 NaN              NaN              NaN               NaN
# 2                 NaN              NaN              NaN               NaN
# 3                 NaN              NaN              NaN               NaN
# 4                 NaN              NaN              NaN               NaN
# ...               ...              ...              ...               ...
# 4435              NaN              NaN              NaN               NaN
# 4436              NaN              NaN              NaN               NaN
# 4437              NaN              NaN              NaN               NaN
# 4438              NaN              NaN              NaN               NaN
# 4439              0.0         0.026704         0.002567               0.0
#
#       val/best/unscaled/loss_a  val/best/unscaled/loss_f  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 4435                       NaN                       NaN
# 4436                       NaN                       NaN
# 4437                       NaN                       NaN
# 4438                       NaN                       NaN
# 4439                       0.0                   0.02677
#
#       val/best/unscaled/loss_l  val/best/unscaled/loss_ce
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 4435                       NaN                        NaN
# 4436                       NaN                        NaN
# 4437                       NaN                        NaN
# 4438                       NaN                        NaN
# 4439                   1.02956                        0.0
#
# [4440 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['lr-AdamW', 'step', 'train/loss', 'train/loss_a', 'train/loss_f',
#        'train/loss_l', 'train/loss_ce', 'train/unscaled/loss_a',
#        'train/unscaled/loss_f', 'train/unscaled/loss_l',
#        'train/unscaled/loss_ce', 'epoch', 'val/loss', 'val/loss_a',
#        'val/loss_f', 'val/loss_l', 'val/loss_ce', 'val/unscaled/loss_a',
#        'val/unscaled/loss_f', 'val/unscaled/loss_l', 'val/unscaled/loss_ce',
#        'val/best/loss', 'val/best/loss_a', 'val/best/loss_f',
#        'val/best/loss_l', 'val/best/loss_ce', 'val/best/unscaled/loss_a',
#        'val/best/unscaled/loss_f', 'val/best/unscaled/loss_l',
#        'val/best/unscaled/loss_ce'],
#       dtype='object')

# %%
xy = df[['step', 'train/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='train loss')
xy = df[['step', 'val/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='val loss')
xy = df[['step', 'val/best/loss']].dropna()
plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], label='val best loss')
plt.legend()
